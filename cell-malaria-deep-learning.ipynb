# %%
import os

# %%
df_dir = 'E:\cell_images\cell_images'

# %%
os.listdir(df_dir)
# Out:
# ['test', 'train']

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# In C:\Users\AZFAR\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AZFAR\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AZFAR\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\AZFAR\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.2'

# %%
from matplotlib.image import imread

# %%
test_path = df_dir+"\\test\\"
train_path = df_dir+"\\train\\"

# %%
test_path
# Out:
# 'E:\\cell_images\\cell_images\\test\\'

# %%
os.listdir(test_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(train_path+'parasitized')[0]
# Out:
# 'C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
para_cell = train_path+'parasitized\\'+'C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
para_cell
# Out:
# 'E:\\cell_images\\cell_images\\train\\parasitized\\C100P61ThinF_IMG_20150918_144104_cell_162.png'

# %%
plt.imshow(imread(para_cell))

# %%
os.listdir(train_path+'uninfected')[0]
# Out:
# 'C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
uninf_cell = train_path+'uninfected\\'+'C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
uninf_cell
# Out:
# 'E:\\cell_images\\cell_images\\train\\uninfected\\C100P61ThinF_IMG_20150918_144104_cell_128.png'

# %%
plt.imshow(imread(uninf_cell))

# %%
pwd
# Out:
# 'C:\\Users\\AZFAR'

# %%
len(os.listdir(train_path+'parasitized'))
# Out:
# 12480

# %%
len(os.listdir(train_path+'uninfected'))
# Out:
# 12480

# %%
dim1=[]
dim2=[]

for img_file in os.listdir(test_path+'uninfected'):
    img = imread(test_path+'uninfected\\'+img_file)
    d1,d2,colors = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
dim1
# Out:
# [118,
#  172,
#  130,
#  163,
#  172,
#  139,
#  151,
#  160,
#  145,
#  127,
#  121,
#  154,
#  145,
#  127,
#  154,
#  151,
#  148,
#  130,
#  160,
#  136,
#  139,
#  190,
#  127,
#  133,
#  136,
#  124,
#  151,
#  151,
#  151,
#  160,
#  118,
#  154,
#  154,
#  121,
#  127,
#  118,
#  130,
#  124,
#  163,
#  88,
#  139,
#  127,
#  121,
#  139,
#  166,
#  133,
#  124,
#  154,
#  139,
#  127,
#  124,
#  136,
#  166,
#  133,
#  145,
#  157,
#  181,
#  148,
#  112,
#  124,
#  112,
#  106,
#  121,
#  148,
#  148,
#  112,
#  121,
#  148,
#  97,
#  112,
#  142,
#  118,
#  130,
#  151,
#  133,
#  136,
#  115,
#  145,
#  115,
#  142,
#  136,
#  130,
#  142,
#  124,
#  142,
#  136,
#  166,
#  148,
#  136,
#  142,
#  133,
#  130,
#  139,
#  124,
#  139,
#  121,
#  130,
#  142,
#  133,
#  118,
#  157,
#  127,
#  109,
#  112,
#  139,
#  142,
#  142,
#  112,
#  118,
#  100,
#  127,
#  145,
#  136,
#  160,
#  187,
#  130,
#  130,
#  157,
#  130,
#  130,
#  151,
#  175,
#  145,
#  136,
#  157,
# ...

# %%
sns.jointplot(x=dim1,y=dim2)

# %%
img_shape = (130,130,3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               shear_range=0.1,
                               zoom_range=0.1,
                               horizontal_flip=True,
                               fill_mode='nearest')

# %%
plt.imshow(imread(para_cell))

# %%
img = imread(para_cell)
image_gen.random_transform(img)
plt.imshow(image_gen.random_transform(img))

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 24958 images belonging to 2 classes.

# %%
image_gen.flow_from_directory(test_path)
# Out:
# Found 2600 images belonging to 2 classes.
